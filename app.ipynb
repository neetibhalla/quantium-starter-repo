# %%
pip install dash jupyter-dash plotly
# Out:
# Requirement already satisfied: dash in c:\users\neeti\appdata\local\python\pythoncore-3.14-64\lib\site-packages (3.3.0)
# Requirement already satisfied: jupyter-dash in c:\users\neeti\appdata\local\python\pythoncore-3.14-64\lib\site-packages (0.4.2)
# Requirement already satisfied: plotly in c:\users\neeti\appdata\local\python\pythoncore-3.14-64\lib\site-packages (6.5.0)
# Requirement already satisfied: Flask<3.2,>=1.0.4 in c:\users\neeti\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from dash) (3.1.2)
# Requirement already satisfied: Werkzeug<3.2 in c:\users\neeti\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from dash) (3.1.4)
# Requirement already satisfied: importlib-metadata in c:\users\neeti\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from dash) (8.7.0)
# Requirement already satisfied: typing_extensions>=4.1.1 in c:\users\neeti\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from dash) (4.15.0)
# Requirement already satisfied: requests in c:\users\neeti\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from dash) (2.32.5)
# Requirement already satisfied: retrying in c:\users\neeti\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from dash) (1.4.2)
# Requirement already satisfied: nest-asyncio in c:\users\neeti\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from dash) (1.6.0)
# Requirement already satisfied: setuptools in c:\users\neeti\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from dash) (80.9.0)
# Requirement already satisfied: blinker>=1.9.0 in c:\users\neeti\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from Flask<3.2,>=1.0.4->dash) (1.9.0)
# Requirement already satisfied: click>=8.1.3 in c:\users\neeti\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from Flask<3.2,>=1.0.4->dash) (8.3.1)
# Requirement already satisfied: itsdangerous>=2.2.0 in c:\users\neeti\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from Flask<3.2,>=1.0.4->dash) (2.2.0)
# Requirement already satisfied: jinja2>=3.1.2 in c:\users\neeti\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from Flask<3.2,>=1.0.4->dash) (3.1.6)
# Requirement already satisfied: markupsafe>=2.1.1 in c:\users\neeti\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from Flask<3.2,>=1.0.4->dash) (3.0.3)
# Requirement already satisfied: ipython in c:\users\neeti\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from jupyter-dash) (9.8.0)
# Requirement already satisfied: ipykernel in c:\users\neeti\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from jupyter-dash) (7.1.0)
# Requirement already satisfied: ansi2html in c:\users\neeti\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from jupyter-dash) (1.9.2)
# Requirement already satisfied: narwhals>=1.15.1 in c:\users\neeti\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from plotly) (2.13.0)
# Requirement already satisfied: packaging in c:\users\neeti\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from plotly) (25.0)
# Requirement already satisfied: colorama in c:\users\neeti\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from click>=8.1.3->Flask<3.2,>=1.0.4->dash) (0.4.6)
# Requirement already satisfied: zipp>=3.20 in c:\users\neeti\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from importlib-metadata->dash) (3.23.0)
# Requirement already satisfied: comm>=0.1.1 in c:\users\neeti\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from ipykernel->jupyter-dash) (0.2.3)
# Requirement already satisfied: debugpy>=1.6.5 in c:\users\neeti\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from ipykernel->jupyter-dash) (1.8.18)
# Requirement already satisfied: jupyter-client>=8.0.0 in c:\users\neeti\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from ipykernel->jupyter-dash) (8.7.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\neeti\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from ipykernel->jupyter-dash) (5.9.1)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\users\neeti\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from ipykernel->jupyter-dash) (0.2.1)
# Requirement already satisfied: psutil>=5.7 in c:\users\neeti\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from ipykernel->jupyter-dash) (7.1.3)
# Requirement already satisfied: pyzmq>=25 in c:\users\neeti\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from ipykernel->jupyter-dash) (27.1.0)
# Requirement already satisfied: tornado>=6.2 in c:\users\neeti\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from ipykernel->jupyter-dash) (6.5.3)
# Requirement already satisfied: traitlets>=5.4.0 in c:\users\neeti\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from ipykernel->jupyter-dash) (5.14.3)
# Requirement already satisfied: decorator>=4.3.2 in c:\users\neeti\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from ipython->jupyter-dash) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers>=1.0.0 in c:\users\neeti\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from ipython->jupyter-dash) (1.1.1)
# Requirement already satisfied: jedi>=0.18.1 in c:\users\neeti\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from ipython->jupyter-dash) (0.19.2)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in c:\users\neeti\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from ipython->jupyter-dash) (3.0.52)
# Requirement already satisfied: pygments>=2.11.0 in c:\users\neeti\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from ipython->jupyter-dash) (2.19.2)
# Requirement already satisfied: stack_data>=0.6.0 in c:\users\neeti\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from ipython->jupyter-dash) (0.6.3)
# Requirement already satisfied: wcwidth in c:\users\neeti\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython->jupyter-dash) (0.2.14)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\users\neeti\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from jedi>=0.18.1->ipython->jupyter-dash) (0.8.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\neeti\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from jupyter-client>=8.0.0->ipykernel->jupyter-dash) (2.9.0.post0)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\neeti\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->jupyter-dash) (4.5.1)
# Requirement already satisfied: six>=1.5 in c:\users\neeti\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from python-dateutil>=2.8.2->jupyter-client>=8.0.0->ipykernel->jupyter-dash) (1.17.0)
# Requirement already satisfied: executing>=1.2.0 in c:\users\neeti\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from stack_data>=0.6.0->ipython->jupyter-dash) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\neeti\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from stack_data>=0.6.0->ipython->jupyter-dash) (3.0.1)
# Requirement already satisfied: pure-eval in c:\users\neeti\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from stack_data>=0.6.0->ipython->jupyter-dash) (0.2.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\neeti\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from requests->dash) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\neeti\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from requests->dash) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\neeti\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from requests->dash) (1.26.20)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\neeti\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from requests->dash) (2025.11.12)
# Note: you may need to restart the kernel to use updated packages.

# %%
from dash import Dash,dcc,html
import plotly.express as px
import pandas as pd
df = pd.read_csv("output.csv")
df["date"] = pd.to_datetime(df["date"])
df = df.sort_values("date")
df
# Out:
#           product   sales region       date
# 0     pink morsel  1731.0   east 2018-02-06
# 1     pink morsel  1638.0  north 2018-02-06
# 2     pink morsel  1647.0  south 2018-02-06
# 3     pink morsel  1557.0   west 2018-02-06
# 4     pink morsel  1542.0   east 2018-02-07
# ...           ...     ...    ...        ...
# 5873  pink morsel  2970.0  north 2022-02-13
# 5877  pink morsel  2830.0  north 2022-02-14
# 5878  pink morsel  2815.0  south 2022-02-14
# 5876  pink morsel  2705.0   east 2022-02-14
# 5879  pink morsel  2945.0   west 2022-02-14
#
# [5880 rows x 4 columns]

# %%
fig = px.line(
    df,
    x="date",
    y="sales",
    title="Sales Over Time",
    labels={"date": "Date", "sales": "Sales"},
)
app = Dash(__name__)

app.layout = html.Div([
    html.H1("Pink Morsel Sales Visualiser", style={"textAlign": "center"}),

    dcc.Graph(
        id="sales-line-chart",
        figure=fig
    )
])

app.run(debug=False, port=8050, use_reloader=False)
# Out:
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8050/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
# Link to Dash App-: https://545a6247-a6bb-4b3b-b1c3-3bb6d32ddb2c.plotly.app
